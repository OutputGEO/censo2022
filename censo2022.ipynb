# %% [markdown]
# <a href="https://colab.research.google.com/github/OutputGEO/censo2022/blob/main/censo2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import folium
from IPython.display import display
from github import Github
import os

# Função para adicionar um banner no topo
def add_banner(map_obj, title, legend):
    banner_html = """
    <div style="
        position: absolute;
        top: 0;
        left: 0;
        width: 100%;
        text-align: left;
        padding: 10px;
        z-index: 1000;
        font-family: 'Arial', sans-serif;
        background-color: #ffffff;
        ">
        <img src="https://raw.githubusercontent.com/OutputGEO/webmap_python/main/banner.png" alt="Banner Image" style="max-width: 100%; max-height: 100px;"> <!-- Define a altura máxima do logo -->
        <h3 style="margin: 5px 0 0 0; font-weight: bold;"><a href="https://www.ibge.gov.br/estatisticas/sociais/populacao/27177-censo-demografico-2022.html" target="_blank">{}</a></h3>
        <p style="margin: 0; font-size: 14px;">{}</p>
    </div>
    """.format(title, legend)
    map_obj.get_root().html.add_child(folium.Element(banner_html))


# Função para adicionar um rodapé com informações da empresa
def add_footer(map_obj, company_info):
    footer_html = """
    <div style="
        position: absolute;
        bottom: 0;
        left: 50%; /* Alinha o rodapé ao centro */
        transform: translateX(-50%); /* Centraliza horizontalmente */
        width: 100%;
        text-align: center; /* Alinha o conteúdo ao centro */
        background-color: #ffffff;
        padding: 10px;
        border-top: 2px solid #000000;
        z-index: 1000;
        ">
        <a href="https://www.outputgeo.com.br" target="_blank"><img src="https://avatars.githubusercontent.com/u/150393907?v=4" alt="OutputGEO Logo" style="max-width: 50px;"></a><br> <!-- Define a largura máxima do logo -->
        <p style="margin: 0;">{}</p>
        <p style="margin: 0;"><a href="mailto:contato@outputgeo.com">contato@outputgeo.com</a> | <a href="https://www.outputgeo.com.br">www.outputgeo.com.br</a></p>
    </div>
    """.format(company_info)
    map_obj.get_root().html.add_child(folium.Element(footer_html))


# URL do arquivo JSON
url = 'https://geoservicos.ibge.gov.br/geoserver/CGMAT/ows?service=WFS&version=2.0.0&request=GetFeature&typeName=CGMAT:qg_2020_600_setcensitario_limites&outputFormat=application/json&Filter=<fes:Filter%20xmlns:fes="http://www.opengis.net/fes/2.0"><PropertyIsEqualTo><PropertyName>cd_mun</PropertyName><Literal>3548708</Literal></PropertyIsEqualTo></fes:Filter>&count=15000'

# Realiza a solicitação GET
response = requests.get(url)

# Verifica se a solicitação foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Converte os dados para o formato JSON
    json_data = response.json()

    # Cria um mapa usando folium
    m = folium.Map(location=[-23.812989, -46.550792], zoom_start=12)

    # Adiciona os polígonos ao mapa com a legenda "Setores censitários"
    folium.GeoJson(json_data,
                   name='Setores censitários',
                   popup=folium.GeoJsonPopup(fields=['cd_setor', 'nm_sit', 'nm_uf', 'cd_mun', 'nm_mun', 'cd_dist', 'nm_dist'],
                                              aliases=['Código do setor: ', 'Situação: ', 'Unidade da Federação: ', 'Código do Município: ', 'Município: ', 'Código do Distrito: ', 'Distrito: '],
                                              localize=True)).add_to(m)

    # Adiciona a camada do mapa de ruas do OSM
    folium.TileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
                     attr='OpenStreetMap',
                     name='Mapa-base - Ruas (OpenStreetMap)',
                     overlay=True).add_to(m)

    # Adiciona a camada de imagem aérea
    folium.TileLayer('https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                     attr='Google Satellite',
                     name='Mapa-base - Imagem Aérea (Google Satellite)',
                     overlay=True).add_to(m)

    # Adiciona banner no topo
    add_banner(m, 'Setores censitários do Município, 2022', 'Dados demográficos, sociais, econômicos e da moradia, segundo setores e domicílios, levantados no Censo Demográfico realizado pelo IBGE')

    # Adiciona informações da empresa no rodapé
    add_footer(m, "OutputGEO Consultoria em Geoprocessamento")

    # Adiciona o controle de camadas ao mapa
    folium.LayerControl(position='bottomleft').add_to(m)

    # Exibe o mapa
    display(m)


import requests
import folium
from IPython.display import display
# !pip install PyGithub  --upgrade
from github import Github
import os

# Função para adicionar um banner no topo
def add_banner(map_obj, title, legend):
    banner_html = """
    <div style="
        position: absolute;
        top: 0;
        left: 0;
        width: 100%;
        text-align: left;
        padding: 10px;
        z-index: 1000;
        font-family: 'Arial', sans-serif;
        background-color: #ffffff;
        ">
        <img src="https://raw.githubusercontent.com/OutputGEO/webmap_python/main/banner.png" alt="Banner Image" style="max-width: 100%; max-height: 100px;"> <!-- Define a altura máxima do logo -->
        <h3 style="margin: 5px 0 0 0; font-weight: bold;"><a href="https://www.ibge.gov.br/estatisticas/sociais/populacao/27177-censo-demografico-2022.html" target="_blank">{}</a></h3>
        <p style="margin: 0; font-size: 14px;">{}</p>
    </div>
    """.format(title, legend)
    map_obj.get_root().html.add_child(folium.Element(banner_html))


# Função para adicionar um rodapé com informações da empresa
def add_footer(map_obj, company_info):
    footer_html = """
    <div style="
        position: absolute;
        bottom: 0;
        left: 50%; /* Alinha o rodapé ao centro */
        transform: translateX(-50%); /* Centraliza horizontalmente */
        width: 100%;
        text-align: center; /* Alinha o conteúdo ao centro */
        background-color: #ffffff;
        padding: 10px;
        border-top: 2px solid #000000;
        z-index: 1000;
        ">
        <a href="https://www.outputgeo.com.br" target="_blank"><img src="https://avatars.githubusercontent.com/u/150393907?v=4" alt="OutputGEO Logo" style="max-width: 50px;"></a><br> <!-- Define a largura máxima do logo -->
        <p style="margin: 0;">{}</p>
        <p style="margin: 0;"><a href="mailto:contato@outputgeo.com">contato@outputgeo.com</a> | <a href="https://www.outputgeo.com.br">www.outputgeo.com.br</a></p>
    </div>
    """.format(company_info)
    map_obj.get_root().html.add_child(folium.Element(footer_html))


# URL do arquivo JSON
url = 'https://geoservicos.ibge.gov.br/geoserver/CGMAT/ows?service=WFS&version=2.0.0&request=GetFeature&typeName=CGMAT:qg_2020_600_setcensitario_limites&outputFormat=application/json&Filter=<fes:Filter%20xmlns:fes="http://www.opengis.net/fes/2.0"><PropertyIsEqualTo><PropertyName>cd_mun</PropertyName><Literal>3548708</Literal></PropertyIsEqualTo></fes:Filter>&count=15000'

# Realiza a solicitação GET
response = requests.get(url)

# Verifica se a solicitação foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Converte os dados para o formato JSON
    json_data = response.json()

    # Cria um mapa usando folium
    m = folium.Map(location=[-23.812989, -46.550792], zoom_start=12)

    # Adiciona os polígonos ao mapa com a legenda "Setores censitários"
    folium.GeoJson(json_data,
                   name='Setores censitários',
                   popup=folium.GeoJsonPopup(fields=['cd_setor', 'nm_sit', 'nm_uf', 'cd_mun', 'nm_mun', 'cd_dist', 'nm_dist'],
                                              aliases=['Código do setor: ', 'Situação: ', 'Unidade da Federação: ', 'Código do Município: ', 'Município: ', 'Código do Distrito: ', 'Distrito: '],
                                              localize=True)).add_to(m)

    # Adiciona a camada do mapa de ruas do OSM
    folium.TileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
                     attr='OpenStreetMap',
                     name='Mapa-base - Ruas (OpenStreetMap)',
                     overlay=True).add_to(m)

    # Adiciona a camada de imagem aérea
    folium.TileLayer('https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                     attr='Google Satellite',
                     name='Mapa-base - Imagem Aérea (Google Satellite)',
                     overlay=True).add_to(m)

    # Adiciona banner no topo
    add_banner(m, 'Setores censitários do Município, 2022', 'Dados demográficos, sociais, econômicos e da moradia, segundo setores e domicílios, levantados no Censo Demográfico realizado pelo IBGE')

    # Adiciona informações da empresa no rodapé
    add_footer(m, "OutputGEO Consultoria em Geoprocessamento")

    # Adiciona o controle de camadas ao mapa
    folium.LayerControl(position='bottomleft').add_to(m)

    # Exibe o mapa
    display(m)



# Salva o mapa como um arquivo HTML temporário no Colab
html_file_path = "mapa_python_wfs_json_ibge.html"
m.save(html_file_path)

# Autenticação no GitHub
g = Github("geooutput@gmail.com", "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")  # Substitua pelo seu email e token de acesso pessoal

# Seleciona o repositório
repo = g.get_user().get_repo("censo2022")  # Substitua pelo nome do seu repositório no GitHub

# Nome do arquivo no GitHub
file_name = "mapa_python_wfs_json_ibge.html"

# Lê o conteúdo do arquivo HTML local
try:
    with open(html_file_path, "r") as file:
        content = file.read()
except FileNotFoundError:
    print("Arquivo HTML não encontrado. Verifique o caminho fornecido.")

# Obtém o SHA do arquivo existente, se existir
try:
    existing_file = repo.get_contents(file_name)
    sha = existing_file.sha
except Exception as e:
    sha = None

# Descrição do commit
commit_message = "Atualizando arquivo HTML com o mapa gerado"

# Tenta criar ou atualizar o arquivo no repositório
try:
    if sha:
        repo.update_file(file_name, commit_message, content, sha, branch="main")
        print("Arquivo atualizado com sucesso no repositório do GitHub!")
    else:
        repo.create_file(file_name, commit_message, content, branch="main")
        print("Arquivo criado com sucesso no repositório do GitHub!")
except Exception as e:
    print("Ocorreu um erro ao criar ou atualizar o arquivo no GitHub:", e)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c522bcf56333d088dc712d8c24d99f60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: absolute;
#         top: 0;
#         left: 0;
#         width: 100%;
#         text-align: left;
#         padding: 10px;
#         z-index: 1000;
#         font-family: &#x27;Arial&#x27;, sans-serif;
#         background-color: #ffffff;
#         &quot;&gt;
#         &lt;img src=&quot;https://raw.githubusercontent.com/OutputGEO/webmap_python/main/banner.png&quot; alt=&quot;Banner Image&quot; style=&quot;max-width: 100%; max-height: 100px;&quot;&gt; &lt;!-- Define a altura máxima do logo --&gt;
#         &lt;h3 style=&quot;margin: 5px 0 0 0; font-weight: bold;&quot;&gt;&lt;a href=&quot;https://www.ibge.gov.br/estatisticas/sociais/populacao/27177-censo-demografico-2022.html&quot; target=&quot;_blank&quot;&gt;Setores censitários do Município, 2022&lt;/a&gt;&lt;/h3&gt;
#         &lt;p style=&quot;margin: 0; font-size: 14px;&quot;&gt;Dados demográficos, sociais, econômicos e da moradia, segundo setores e domicílios, levantados no Censo Demográfico realizado pelo IBGE&lt;/p&gt;
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;
#         position: absolute;
#         bottom: 0;
#         left: 50%; /* Alinha o rodapé ao centro */
#         transform: translateX(-50%); /* Centraliza horizontalmente */
#         width: 100%;
#         text-align: center; /* Alinha o conteúdo ao centro */
#         background-color: #ffffff;
#         padding: 10px;
#         border-top: 2px solid #000000;
#         z-index: 1000;
#         &quot;&gt;
#         &lt;a href=&quot;https://www.outputgeo.com.br&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;https://avatars.githubusercontent.com/u/150393907?v=4&quot; alt=&quot;OutputGEO Logo&quot; style=&quot;max-width: 50px;&quot;&gt;&lt;/a&gt;&lt;br&gt; &lt;!-- Define a largura máxima do logo --&gt;
#         &lt;p style=&quot;margin: 0;&quot;&gt;OutputGEO Consultoria em Geoprocessamento&lt;/p&gt;
#         &lt;p style=&quot;margin: 0;&quot;&gt;&lt;a href=&quot;mailto:contato@outputgeo.com&quot;&gt;contato@outputgeo.com&lt;/a&gt; | &lt;a href=&quot;https://www.outputgeo.com.br&quot;&gt;www.outputgeo.com.br&lt;/a&gt;&lt;/p&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c522bcf56333d088dc712d8c24d99f60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c522bcf56333d088dc712d8c24d99f60 = L.map(
#                 &quot;map_c522bcf56333d088dc712d8c24d99f60&quot;,
#                 {
#                     center: [-23.812989, -46.550792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a89b6dc4a484f53ed38931abf5a334c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c522bcf56333d088dc712d8c24d99f60);
#
#
#
#         function geo_json_1faa445e7dab1cff95ac9099e5f86510_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1faa445e7dab1cff95ac9099e5f86510 = L.geoJson(null, {
#                 onEachFeature: geo_json_1faa445e7dab1cff95ac9099e5f86510_onEachFeature,
#
#         });
#
#         function geo_json_1faa445e7dab1cff95ac9099e5f86510_add (data) {
#             geo_json_1faa445e7dab1cff95ac9099e5f86510
#                 .addData(data)
#                 .addTo(map_c522bcf56333d088dc712d8c24d99f60);
#         }
#             geo_json_1faa445e7dab1cff95ac9099e5f86510_add({&quot;bbox&quot;: [-46.652046, -23.967918, -46.410296, -23.641036], &quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::4674&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;bbox&quot;: [-46.5352593, -23.7098954, -46.53492541, -23.70910261], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-46.53493112, -23.70910781], [-46.53492541, -23.70988993], [-46.53496999, -23.7098954], [-46.5352593, -23.70988461], [-46.53525746, -23.70962353], [-46.53525387, -23.70911339], [-46.53497889, -23.70910261], [-46.53493112, -23.70910781]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;geometry_name&quot;: &quot;geom&quot;, &quot;id&quot;: &quot;qg_2020_600_setcensitario_limites.fid-5e015429_18ea769e9cc_1d0d&quot;, &quot;properties&quot;: {&q
# Arquivo HTML não encontrado. Verifique o caminho fornecido.
# Arquivo atualizado com sucesso no repositório do GitHub!
